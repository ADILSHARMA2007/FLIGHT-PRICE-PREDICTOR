# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('D:\FLIGHT PRICE PREDICTOR\BASE\clean_flight_dataset1.csv')

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df["DISTANCE_BIN"] = pd.qcut(df["DISTANCE"], q=5)

# %%
df["DISTANCE_BIN"].value_counts()
# Out:
# DISTANCE_BIN
# (316.0, 516.0]      990129
# (30.999, 316.0]     984416
# (757.0, 1068.0]     982803
# (1068.0, 2130.0]    982009
# (516.0, 757.0]      976996
# Name: count, dtype: int64

# %%
df.to_csv('D:\FLIGHT PRICE PREDICTOR\BASE\clean_flight_dataset1.csv', index=False)

# %%
df.shape
# Out:
# (4916353, 19)

# %%
df.head(10)
# Out:
#    MONTH  DAY  DAY_OF_WEEK ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_TIME  \
# 0      1    1            4            ANC                 SEA           205.0
# 1      1    1            4            SEA                 ANC           235.0
# 2      1    1            4            SFO                 MSP           217.0
# 3      1    1            4            LAS                 MSP           181.0
# 4      1    1            4            SFO                 DFW           195.0
# 5      1    1            4            LAS                 ATL           221.0
# 6      1    1            4            DEN                 ATL           173.0
# 7      1    1            4            LAX                 MSP           214.0
# 8      1    1            4            SLC                 ATL           215.0
# 9      1    1            4            SEA                 MSP           189.0
#
#    DISTANCE    FARE                 AIRLINE  DEP_HOUR  ARR_HOUR  DEP_MIN  \
# ...

# %%
df.drop('FARE_PER_MILE', axis=1, inplace=True)

# %%
df.to_csv('D:\FLIGHT PRICE PREDICTOR\BASE\clean_flight_dataset1.csv', index=False)

# %%
df.head(10)
# Out:
#    MONTH  DAY  DAY_OF_WEEK ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_TIME  \
# 0      1    1            4            ANC                 SEA           205.0
# 1      1    1            4            SEA                 ANC           235.0
# 2      1    1            4            SFO                 MSP           217.0
# 3      1    1            4            LAS                 MSP           181.0
# 4      1    1            4            SFO                 DFW           195.0
# 5      1    1            4            LAS                 ATL           221.0
# 6      1    1            4            DEN                 ATL           173.0
# 7      1    1            4            LAX                 MSP           214.0
# 8      1    1            4            SLC                 ATL           215.0
# 9      1    1            4            SEA                 MSP           189.0
#
#    DISTANCE    FARE                 AIRLINE  DEP_HOUR  ARR_HOUR  DEP_MIN  \
# ...

# %%
df.shape
# Out:
# (4916353, 18)
